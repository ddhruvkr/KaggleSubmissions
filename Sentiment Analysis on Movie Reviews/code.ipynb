# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('./train.tsv', sep='\t', header=0)
trainX = np.array(list(data['Phrase']))
trainY = np.array(list(data['Sentiment']));

# %%
length=-1
for x in trainX:
    if length < len(x):
        length=len(x)
print(length)
# Out:
# 283

# %%
data = pd.read_csv('./test.tsv', sep='\t', header=0)
testX=np.array(list(data['Phrase']))

# %%
testX
# Out:
# array(['An intermittently pleasing but mostly routine effort .',
#        'An intermittently pleasing but mostly routine effort', 'An', ...,
#        'A long-winded ,', 'A long-winded', 'predictable scenario'],
#       dtype='<U256')

# %%
# once we have the data, we would need to convert it into tokens i.e. represent each unique work with a unique integer.
# this could be done by keras tokenizer
from keras.preprocessing.text import Tokenizer
tokenizer = Tokenizer()
tokenizer.fit_on_texts(np.concatenate((trainX, testX), axis=0))
# Tokenizer.fit_on_texts(X_train)
tokenizer_vocab_size = len(tokenizer.word_index) + 1
print ("Vocab size",tokenizer_vocab_size)
# Out:
# Using TensorFlow backend.
# Vocab size 17781

# %%
tokenizer.word_index
# Out:
# {'the': 1,
#  'a': 2,
#  'of': 3,
#  'and': 4,
#  'to': 5,
#  "'s": 6,
#  'in': 7,
#  'is': 8,
#  'that': 9,
#  'it': 10,
#  'as': 11,
#  'with': 12,
#  'for': 13,
#  'its': 14,
#  'film': 15,
#  'an': 16,
#  'movie': 17,
#  'this': 18,
#  'but': 19,
#  'be': 20,
#  'on': 21,
#  'you': 22,
#  'by': 23,
#  "n't": 24,
#  'more': 25,
#  'his': 26,
#  'not': 27,
#  'one': 28,
#  'than': 29,
#  'about': 30,
#  'at': 31,
#  'from': 32,
#  'or': 33,
#  'all': 34,
#  'like': 35,
#  'are': 36,
#  'have': 37,
#  'has': 38,
#  'so': 39,
#  "'": 40,
#  'out': 41,
#  'story': 42,
#  'who': 43,
#  'rrb': 44,
#  'up': 45,
#  'too': 46,
#  'good': 47,
#  'most': 48,
#  'into': 49,
#  'lrb': 50,
#  'time': 51,
#  'much': 52,
#  'what': 53,
#  'if': 54,
#  'characters': 55,
#  'no': 56,
#  'comedy': 57,
#  'their': 58,
#  'just': 59,
#  'i': 60,
#  'some': 61,
#  'can': 62,
#  'even': 63,
#  'life': 64,
#  'your': 65,
#  'little': 66,
#  'does': 67,
#  "''": 68,
#  'way': 69,
#  'well': 70,
#  'will': 71,
#  'make': 72,
#  'been': 73,
#  'funny': 74,
#  'only': 75,
#  'very': 76,
#  'he': 77,
#  'do': 78,
#  'director': 79,
#  'any': 80,
#  'enough': 81,
#  'us': 82,
#  'her': 83,
#  'bad': 84,
#  'there': 85,
#  'new': 86,
#  'love': 87,
#  'movies': 88,
#  'which': 89,
#  'they': 90,
#  'was': 91,
#  'work': 92,
#  'two': 93,
#  'own': 94,
#  'them': 95,
#  'best': 96,
#  'when': 97,
#  'action': 98,
#  'old': 99,
#  'something': 100,
#  'made': 101,
#  'we': 102,
#  'through': 103,
#  'other': 104,
#  'people': 105,
#  'never': 106,
#  'off': 107,
#  'makes': 108,
#  'would': 109,
#  'world': 110,
#  'see': 111,
#  'many': 112,
#  'character': 113,
#  'films': 114,
#  'self': 115,
#  'could': 116,
#  'how': 117,
#  'long': 118,
#  'over': 119,
#  'big': 120,
#  'may': 121,
#  'plot': 122,
#  'get': 123,
#  'first': 124,
#  'look': 125,
#  'audience': 126,
#  'being': 127,
#  'those': 128,
#  'every': 129,
#  'performances': 130,
#  'drama': 131,
#  'better': 132,
#  'great': 133,
#  'real': 134,
#  'really': 135,
#  'humor': 136,
#  'fun': 137,
#  'sense': 138,
#  "'re": 139,
#  'screen': 140,
#  'should': 141,
#  'man': 142,
#  'another': 143,
#  'year': 144,
#  'few': 145,
#  'feel': 146,
#  'still': 147,
#  'without': 148,
#  'both': 149,
#  'minutes': 150,
#  'ever': 151,
#  'hollywood': 152,
#  'cast': 153,
#  'american': 154,
#  'such': 155,
#  'down': 156,
#  'while': 157,
#  'kind': 158,
#  'human': 159,
#  'less': 160,
#  'nothing': 161,
#  'heart': 162,
#  'between': 163,
#  'far': 164,
#  'might': 165,
#  'full': 166,
#  'interesting': 167,
#  'hard': 168,
#  'performance': 169,
#  'family': 170,
#  'script': 171,
#  'seen': 172,
#  'our': 173,
#  'because': 174,
#  'rather': 175,
#  'thriller': 176,
#  'often': 177,
#  'picture': 178,
#  'right': 179,
#  'my': 180,
#  'same': 181,
#  'acting': 182,
#  'had': 183,
#  'these': 184,
#  'were': 185,
#  'original': 186,
#  'also': 187,
#  'go': 188,
#  'tale': 189,
#  'moments': 190,
#  'things': 191,
#  'quite': 192,
#  'back': 193,
#  'emotional': 194,
#  'almost': 195,
#  'take': 196,
#  'itself': 197,
#  'end': 198,
#  'young': 199,
#  'before': 200,
#  'thing': 201,
#  'here': 202,
#  'after': 203,
#  'going': 204,
#  'music': 205,
#  'times': 206,
#  'watching': 207,
#  'entertaining': 208,
#  'scenes': 209,
#  'dialogue': 210,
#  "'ve": 211,
#  'star': 212,
#  'romantic': 213,
#  'cinema': 214,
#  'ca': 215,
#  'actors': 216,
#  'find': 217,
#  'watch': 218,
#  'material': 219,
#  'where': 220,
#  'come': 221,
#  'lot': 222,
#  'war': 223,
#  'kids': 224,
#  'documentary': 225,
#  'half': 226,
#  'style': 227,
#  'video': 228,
#  'high': 229,
#  'years': 230,
#  'seems': 231,
#  'me': 232,
#  'yet': 233,
#  "'ll": 234,
#  'last': 235,
#  'though': 236,
#  'feels': 237,
#  'point': 238,
#  'special': 239,
#  'show': 240,
#  'know': 241,
#  'give': 242,
#  'history': 243,
#  'compelling': 244,
#  'takes': 245,
#  'subject': 246,
#  'him': 247,
#  'worth': 248,
#  'anything': 249,
#  'comes': 250,
#  'art': 251,
#  'entertainment': 252,
#  'making': 253,
#  'gets': 254,
#  'did': 255,
#  'least': 256,
#  'women': 257,
#  'say': 258,
#  'three': 259,
#  'keep': 260,
#  'around': 261,
#  'cinematic': 262,
#  'true': 263,
#  'seem': 264,
#  'pretty': 265,
#  'ultimately': 266,
#  'part': 267,
#  'tv': 268,
#  'care': 269,
#  'think': 270,
#  'want': 271,
#  'sweet': 272,
#  'dark': 273,
#  'together': 274,
#  'away': 275,
#  'theater': 276,
#  'laughs': 277,
#  'day': 278,
#  'works': 279,
#  'place': 280,
#  'flick': 281,
#  'anyone': 282,
#  'writer': 283,
#  'moving': 284,
#  'piece': 285,
#  'horror': 286,
#  'fans': 287,
#  'comic': 288,
#  'bit': 289,
#  'need': 290,
#  'visual': 291,
#  'effects': 292,
#  'again': 293,
#  'once': 294,
#  'sometimes': 295,
#  'feature': 296,
#  'low': 297,
#  'then': 298,
#  'silly': 299,
#  'nearly': 300,
#  'set': 301,
#  'looking': 302,
#  'narrative': 303,
#  'dull': 304,
#  'direction': 305,
#  'familiar': 306,
#  'under': 307,
#  'why': 308,
#  'fascinating': 309,
#  'genre': 310,
#  'whose': 311,
#  'she': 312,
#  'clever': 313,
#  'mind': 314,
#  'series': 315,
#  'children': 316,
#  'actually': 317,
#  'whole': 318,
#  'face': 319,
#  'hour': 320,
#  'age': 321,
#  'minute': 322,
#  'done': 323,
#  'gives': 324,
#  'past': 325,
#  'experience': 326,
#  'men': 327,
#  'power': 328,
#  'since': 329,
#  'trying': 330,
#  'charm': 331,
#  'girl': 332,
#  'modern': 333,
#  'lives': 334,
#  'always': 335,
#  'title': 336,
#  'culture': 337,
#  'interest': 338,
#  'next': 339,
#  'idea': 340,
#  'black': 341,
#  'level': 342,
#  'predictable': 343,
#  'small': 344,
#  'coming': 345,
#  'classic': 346,
#  'book': 347,
#  'school': 348,
#  'feeling': 349,
#  'matter': 350,
#  'study': 351,
#  'light': 352,
#  'simply': 353,
#  'intelligent': 354,
#  'wit': 355,
#  'amusing': 356,
#  'live': 357,
#  'mr': 358,
#  'short': 359,
#  'romance': 360,
#  'screenplay': 361,
#  'head': 362,
#  'enjoyable': 363,
#  'smart': 364,
#  'become': 365,
#  'actor': 366,
#  'easy': 367,
#  'thought': 368,
#  'instead': 369,
#  'each': 370,
#  'ideas': 371,
#  'strong': 372,
#  'summer': 373,
#  'everything': 374,
#  'play': 375,
#  'serious': 376,
#  'woman': 377,
#  'premise': 378,
#  'middle': 379,
#  'everyone': 380,
#  'fresh': 381,
#  'especially': 382,
#  'reality': 383,
#  'put': 384,
#  'despite': 385,
#  'john': 386,
#  'hours': 387,
#  'energy': 388,
#  'worst': 389,
#  'himself': 390,
#  'quirky': 391,
#  'obvious': 392,
#  'lack': 393,
#  'enjoy': 394,
#  'home': 395,
#  'engaging': 396,
#  'effort': 397,
#  'de': 398,
#  'version': 399,
#  'stuff': 400,
#  'dramatic': 401,
#  'charming': 402,
#  'suspense': 403,
#  'french': 404,
#  'filmmaker': 405,
#  'solid': 406,
#  'filmmakers': 407,
#  'now': 408,
#  'spirit': 409,
#  "'d": 410,
#  'death': 411,
#  'jokes': 412,
#  'debut': 413,
#  'written': 414,
#  'likely': 415,
#  'slow': 416,
#  'recent': 417,
#  'message': 418,
#  'filmmaking': 419,
#  'adventure': 420,
#  'shot': 421,
#  'camera': 422,
#  'perfect': 423,
#  'powerful': 424,
#  'stories': 425,
#  'role': 426,
#  'sort': 427,
#  'political': 428,
#  'laugh': 429,
#  'leave': 430,
#  'else': 431,
#  'beautiful': 432,
#  'fine': 433,
#  'ending': 434,
#  'either': 435,
#  'different': 436,
#  'tone': 437,
#  'truly': 438,
#  'directed': 439,
#  'opera': 440,
#  'line': 441,
#  'melodrama': 442,
#  'goes': 443,
#  'side': 444,
#  'probably': 445,
#  'portrait': 446,
#  'production': 447,
#  'manages': 448,
#  'scene': 449,
#  'stand': 450,
#  'viewers': 451,
#  'project': 452,
#  'heavy': 453,
#  'class': 454,
#  'turns': 455,
#  'reason': 456,
#  'sex': 457,
#  'along': 458,
#  'believe': 459,
#  'crime': 460,
#  'beyond': 461,
#  'dead': 462,
#  'audiences': 463,
#  'surprisingly': 464,
#  'wo': 465,
#  'dumb': 466,
#  'run': 467,
#  'becomes': 468,
#  'rare': 469,
#  'turn': 470,
#  'offers': 471,
#  'social': 472,
#  'passion': 473,
#  'boring': 474,
#  'boy': 475,
#  'second': 476,
#  'simple': 477,
#  'impossible': 478,
#  'talent': 479,
#  'sure': 480,
#  'close': 481,
#  'completely': 482,
#  'novel': 483,
#  'intelligence': 484,
#  'disney': 485,
#  'intriguing': 486,
#  'left': 487,
#  'personal': 488,
#  'game': 489,
#  'deeply': 490,
#  'sad': 491,
#  'exercise': 492,
#  'ends': 493,
#  'ride': 494,
#  'above': 495,
#  'act': 496,
#  'budget': 497,
#  'eye': 498,
#  'complex': 499,
#  'acted': 500,
#  'tell': 501,
#  'pleasure': 502,
#  'moral': 503,
#  'ways': 504,
#  'satisfying': 505,
#  'eyes': 506,
#  'spy': 507,
#  'b': 508,
#  'pop': 509,
#  'writing': 510,
#  'cool': 511,
#  'tragedy': 512,
#  'michael': 513,
#  'mystery': 514,
#  'fact': 515,
#  'formula': 516,
#  'honest': 517,
#  'teen': 518,
#  'difficult': 519,
#  'gags': 520,
#  'possible': 521,
#  'themselves': 522,
#  'important': 523,
#  'hero': 524,
#  'nature': 525,
#  'easily': 526,
#  'wrong': 527,
#  'mostly': 528,
#  'already': 529,
#  'comedies': 530,
#  'creepy': 531,
#  'having': 532,
#  'flat': 533,
#  'shows': 534,
#  'form': 535,
#  'violence': 536,
#  'images': 537,
#  'rock': 538,
#  'top': 539,
#  'days': 540,
#  'concept': 541,
#  'career': 542,
#  'four': 543,
#  'mess': 544,
#  'particularly': 545,
#  'insight': 546,
#  'thin': 547,
#  'whether': 548,
#  'touching': 549,
#  'hit': 550,
#  'cold': 551,
#  'storytelling': 552,
#  'otherwise': 553,
#  'viewer': 554,
#  'future': 555,
#  'seeing': 556,
#  'looks': 557,
#  'rich': 558,
#  'plays': 559,
#  'hilarious': 560,
#  'attempt': 561,
#  'imagination': 562,
#  'single': 563,
#  'night': 564,
#  'final': 565,
#  'exactly': 566,
#  'oscar': 567,
#  'running': 568,
#  'cliches': 569,
#  'truth': 570,
#  'gentle': 571,
#  'fantasy': 572,
#  'against': 573,
#  'deep': 574,
#  'visually': 575,
#  'white': 576,
#  'working': 577,
#  "'m": 578,
#  'animation': 579,
#  'house': 580,
#  'tries': 581,
#  'attention': 582,
#  'memorable': 583,
#  'help': 584,
#  'must': 585,
#  'straight': 586,
#  'beauty': 587,
#  'city': 588,
#  'beautifully': 589,
#  'getting': 590,
#  'psychological': 591,
#  'occasionally': 592,
#  'elements': 593,
#  'guys': 594,
#  'taste': 595,
#  'terrific': 596,
#  'hand': 597,
#  'inside': 598,
#  'several': 599,
#  'worthy': 600,
#  'period': 601,
#  'adults': 602,
#  'soap': 603,
#  'approach': 604,
#  'lead': 605,
#  'fi': 606,
#  'gone': 607,
#  'doing': 608,
#  'lacks': 609,
#  'cultural': 610,
#  'usual': 611,
#  'given': 612,
#  'sequel': 613,
#  'during': 614,
#  'pictures': 615,
#  'got': 616,
#  'none': 617,
#  'sci': 618,
#  'quality': 619,
#  'found': 620,
#  'certainly': 621,
#  'strange': 622,
#  'emotionally': 623,
#  'decent': 624,
#  'nor': 625,
#  'journey': 626,
#  'parents': 627,
#  'historical': 628,
#  'free': 629,
#  'pretentious': 630,
#  'moment': 631,
#  'america': 632,
#  'change': 633,
#  'cheap': 634,
#  'epic': 635,
#  'neither': 636,
#  'fire': 637,
#  'cute': 638,
#  'cut': 639,
#  'case': 640,
#  'view': 641,
#  'fairly': 642,
#  'depth': 643,
#  'vision': 644,
#  'open': 645,
#  'told': 646,
#  'issues': 647,
#  'dog': 648,
#  'behind': 649,
#  'lost': 650,
#  'sit': 651,
#  'bring': 652,
#  'air': 653,
#  'entire': 654,
#  'fails': 655,
#  'artist': 656,
#  'guy': 657,
#  '2': 658,
#  'genuine': 659,
#  'mood': 660,
#  'expect': 661,
#  'events': 662,
#  'sequences': 663,
#  'earnest': 664,
#  'brilliant': 665,
#  'road': 666,
#  'ones': 667,
#  'clear': 668,
#  'contrived': 669,
#  'contemporary': 670,
#  'monster': 671,
#  'soul': 672,
#  'relationship': 673,
#  'major': 674,
#  'taking': 675,
#  'knows': 676,
#  'mean': 677,
#  'others': 678,
#  'hip': 679,
#  'scary': 680,
#  'previous': 681,
#  'emotions': 682,
#  'pace': 683,
#  'job': 684,
#  'loud': 685,
#  'winning': 686,
#  'entirely': 687,
#  'delivers': 688,
#  'water': 689,
#  'college': 690,
#  'remains': 691,
#  'tragic': 692,
#  'warm': 693,
#  'gorgeous': 694,
#  'joke': 695,
#  'ago': 696,
#  'crowd': 697,
#  'problem': 698,
#  'barely': 699,
#  'wonderful': 700,
#  'sexual': 701,
#  'nice': 702,
#  'kid': 703,
#  'creative': 704,
#  'meaning': 705,
#  'ugly': 706,
#  'appeal': 707,
#  'fully': 708,
#  'fast': 709,
#  '90': 710,
#  'satire': 711,
#  'thinking': 712,
#  'memory': 713,
#  'stars': 714,
#  'deal': 715,
#  'call': 716,
#  'adaptation': 717,
#  'surprising': 718,
#  'try': 719,
#  'keeps': 720,
#  'playing': 721,
#  'worse': 722,
#  'sentimental': 723,
#  'perfectly': 724,
#  'latest': 725,
#  'co': 726,
#  'living': 727,
#  'points': 728,
#  'bland': 729,
#  'television': 730,
#  'animated': 731,
#  'century': 732,
#  'needs': 733,
#  'talented': 734,
#  'excellent': 735,
#  'remarkable': 736,
#  'uses': 737,
#  'large': 738,
#  'appealing': 739,
#  'welcome': 740,
#  'somewhat': 741,
#  'hope': 742,
#  'urban': 743,
#  'impact': 744,
#  'david': 745,
#  'tension': 746,
#  '10': 747,
#  'among': 748,
#  'plenty': 749,
#  'trip': 750,
#  'car': 751,
#  'tired': 752,
#  'remake': 753,
#  'situation': 754,
#  'supposed': 755,
#  'fashioned': 756,
#  'start': 757,
#  'room': 758,
#  'thoughtful': 759,
#  'flicks': 760,
#  'ambitious': 761,
#  'sound': 762,
#  'magic': 763,
#  'robert': 764,
#  'york': 765,
#  'sustain': 766,
#  'today': 767,
#  'potential': 768,
#  'bond': 769,
#  'able': 770,
#  'wild': 771,
#  'length': 772,
#  'female': 773,
#  'proves': 774,
#  'ii': 775,
#  'giving': 776,
#  'date': 777,
#  'target': 778,
#  'stupid': 779,
#  'certain': 780,
#  'couple': 781,
#  'company': 782,
#  'force': 783,
#  'country': 784,
#  'gross': 785,
#  'offer': 786,
#  'british': 787,
#  'ya': 788,
#  'cartoon': 789,
#  'finally': 790,
#  'utterly': 791,
#  'process': 792,
#  'someone': 793,
#  'skin': 794,
#  'create': 795,
#  'lots': 796,
#  'called': 797,
#  'relationships': 798,
#  'used': 799,
#  'business': 800,
#  'brain': 801,
#  'wonder': 802,
#  'girls': 803,
#  'boys': 804,
#  'leaves': 805,
#  'surprise': 806,
#  'hell': 807,
#  'inventive': 808,
#  'let': 809,
#  'convincing': 810,
#  'use': 811,
#  'touch': 812,
#  'based': 813,
#  'non': 814,
#  'hold': 815,
#  'post': 816,
#  'dry': 817,
#  'name': 818,
#  'actress': 819,
#  'sentimentality': 820,
#  'bizarre': 821,
#  'average': 822,
#  'conflict': 823,
#  'era': 824,
#  'unsettling': 825,
#  'yourself': 826,
#  'sharp': 827,
#  'miss': 828,
#  'felt': 829,
#  'throughout': 830,
#  'odd': 831,
#  's': 832,
#  'falls': 833,
#  'grace': 834,
#  'episode': 835,
#  'impressive': 836,
#  'slightly': 837,
#  'formulaic': 838,
#  'across': 839,
#  'themes': 840,
#  'substance': 841,
#  'money': 842,
#  'happy': 843,
#  'sports': 844,
#  'wife': 845,
#  'awful': 846,
#  'unexpected': 847,
#  'alone': 848,
#  'read': 849,
#  'add': 850,
#  'edge': 851,
#  'thoroughly': 852,
#  'quiet': 853,
#  'success': 854,
#  'examination': 855,
#  'starts': 856,
#  'imagine': 857,
#  'loss': 858,
#  'ensemble': 859,
#  'paced': 860,
#  'george': 861,
#  'merely': 862,
#  'surprises': 863,
#  'indie': 864,
#  'gay': 865,
#  'highly': 866,
#  'person': 867,
#  'effective': 868,
#  'pure': 869,
#  'core': 870,
#  'manner': 871,
#  'subtle': 872,
#  'lovely': 873,
#  'engrossing': 874,
#  'until': 875,
#  'numbers': 876,
#  'perhaps': 877,
#  'politics': 878,
#  'inspired': 879,
#  'five': 880,
#  'involved': 881,
#  'soundtrack': 882,
#  'chemistry': 883,
#  'understand': 884,
#  'wanted': 885,
#  'ultimate': 886,
#  'exciting': 887,
#  'interested': 888,
#  'waste': 889,
#  'break': 890,
#  'witty': 891,
#  'hot': 892,
#  'wants': 893,
#  'crazy': 894,
#  'pay': 895,
#  'mildly': 896,
#  'questions': 897,
#  'brothers': 898,
#  'share': 899,
#  'provocative': 900,
#  'spiritual': 901,
#  'although': 902,
#  'mediocre': 903,
#  'overall': 904,
#  'casting': 905,
#  'master': 906,
#  'flaws': 907,
#  'ill': 908,
#  'mother': 909,
#  'words': 910,
#  'battle': 911,
#  'generation': 912,
#  'considerable': 913,
#  'flawed': 914,
#  'maybe': 915,
#  'promise': 916,
#  'third': 917,
#  'dream': 918,
#  'party': 919,
#  'voice': 920,
#  'frame': 921,
#  'typical': 922,
#  'franchise': 923,
#  'begins': 924,
#  'stylish': 925,
#  'taken': 926,
#  'trouble': 927,
#  'slapstick': 928,
#  'seat': 929,
#  'filled': 930,
#  'murder': 931,
#  'drag': 932,
#  'sophisticated': 933,
#  'unique': 934,
#  'child': 935,
#  'plain': 936,
#  'unfunny': 937,
#  'colorful': 938,
#  'sincere': 939,
#  'key': 940,
#  'saw': 941,
#  'twists': 942,
#  'badly': 943,
#  'painful': 944,
#  'extreme': 945,
#  'equally': 946,
#  'fiction': 947,
#  'poor': 948,
#  'question': 949,
#  'giant': 950,
#  'believable': 951,
#  'ability': 952,
#  'problems': 953,
#  'evil': 954,
#  'humanity': 955,
#  'red': 956,
#  'tedious': 957,
#  'ages': 958,
#  'warmth': 959,
#  'central': 960,
#  'sensitive': 961,
#  'bright': 962,
#  'indulgent': 963,
#  'execution': 964,
#  'spielberg': 965,
#  'handed': 966,
#  'successful': 967,
#  'intimate': 968,
#  'friendship': 969,
#  'blood': 970,
#  'course': 971,
#  'screenwriter': 972,
#  'guilty': 973,
#  'niro': 974,
#  'attempts': 975,
#  'williams': 976,
#  'steven': 977,
#  'natural': 978,
#  'public': 979,
#  'forced': 980,
#  'terrible': 981,
#  'situations': 982,
#  'green': 983,
#  'brings': 984,
#  'goofy': 985,
#  'shoot': 986,
#  'recommend': 987,
#  'mark': 988,
#  'society': 989,
#  'masterpiece': 990,
#  'standard': 991,
#  'artistic': 992,
#  'produced': 993,
#  'terms': 994,
#  'computer': 995,
#  'list': 996,
#  'mix': 997,
#  'grief': 998,
#  'talk': 999,
#  'places': 1000,
#  ...}

# %%
trainX
trainX[32000:]
# Out:
# array(['has considerable charm .', 'has considerable charm',
#        'considerable charm', ..., 'avuncular chortles', 'avuncular',
#        'chortles'],
#       dtype='<U283')

# %%
trainX
# Out:
# array([ 'A series of escapades demonstrating the adage that what is good for the goose is also good for the gander , some of which occasionally amuses but none of which amounts to much of a story .',
#        'A series of escapades demonstrating the adage that what is good for the goose',
#        'A series', ..., 'avuncular chortles', 'avuncular', 'chortles'],
#       dtype='<U283')

# %%
# next step is to convert this to word embeddings
# but first we need to convert the whole array of text to array of numbers as we indexed them previously
# currently i am not putting validation data in this conversion
# therefore just making two sets of conversion text to number encodings(training and test data, no validation data)
# 
encoded_words_train = tokenizer.texts_to_sequences(trainX)
encoded_words_test = tokenizer.texts_to_sequences(testX)
print(encoded_words_test)
# Out:
# [[16, 2855, 1810, 19, 528, 1020, 397], [16, 2855, 1810, 19, 528, 1020, 397], [16], [2855, 1810, 19, 528, 1020, 397], [2855, 1810, 19, 528, 1020], [2855, 1810, 19], [2855, 1810], [2855], [1810], [19], [528, 1020], [528], [1020], [397], [], [4981, 8, 135, 1, 75, 201, 9, 6, 248, 207, 7, 2493, 332, 2, 15, 23, 1, 1122, 5944, 5649, 5650, 50, 5550, 44, 9, 1563, 11, 233, 143, 1628, 3, 1, 491, 7219, 3, 787, 530, 7, 1, 816, 166, 1221, 110], [4981], [8, 135, 1, 75, 201, 9, 6, 248, 207, 7, 2493, 332, 2, 15, 23, 1, 1122, 5944, 5649, 5650, 50, 5550, 44, 9, 1563, 11, 233, 143, 1628, 3, 1, 491, 7219, 3, 787, 530, 7, 1, 816, 166, 1221, 110], [8, 135, 1, 75, 201, 9, 6, 248, 207, 7, 2493, 332, 2, 15, 23, 1, 1122, 5944, 5649, 5650, 50, 5550, 44, 9, 1563, 11, 233, 143, 1628, 3, 1, 491, 7219, 3, 787, 530, 7, 1, 816, 166, 1221, 110], [8, 135], [8], [135], [1, 75, 201, 9, 6, 248, 207, 7, 2493, 332, 2, 15, 23, 1, 1122, 5944, 5649, 5650, 50, 5550, 44, 9, 1563, 11, 233, 143, 1628, 3, 1, 491, 7219, 3, 787, 530, 7, 1, 816, 166, 1221, 110], [1, 75, 201], [1], [75, 201], [75], [201], [9, 6, 248, 207, 7, 2493, 332, 2, 15, 23, 1, 1122, 5944, 5649, 5650, 50, 5550, 44, 9, 1563, 11, 233, 143, 1628, 3, 1, 491, 7219, 3, 787, 530, 7, 1, 816, 166, 1221, 110], [9], [6, 248, 207, 7, 2493, 332, 2, 15, 23, 1, 1122, 5944, 5649, 5650, 50, 5550, 44, 9, 1563, 11, 233, 143, 1628, 3, 1, 491, 7219, 3, 787, 530, 7, 1, 816, 166, 1221, 110], [6, 248, 207, 7, 2493, 332, 2, 15, 23, 1, 1122, 5944, 5649, 5650, 50, 5550, 44, 9, 1563, 11, 233, 143, 1628, 3, 1, 491, 7219, 3, 787, 530], [6, 248, 207, 7, 2493, 332, 2, 15, 23, 1, 1122, 5944, 5649, 5650, 50, 5550, 44, 9, 1563], [6, 248], [6], [248], [207, 7, 2493, 332, 2, 15, 23, 1, 1122, 5944, 5649, 5650, 50, 5550, 44, 9, 1563], [207, 7, 2493, 332, 2, 15], [207], [7, 2493, 332, 2, 15], [7], [2493, 332, 2, 15], [2493, 332], [2493, 332], [2493], [332], [], [2, 15], [2], [15], [23, 1, 1122, 5944, 5649, 5650, 50, 5550, 44, 9, 1563], [23], [1, 1122, 5944, 5649, 5650, 50, 5550, 44, 9, 1563], [1, 1122, 5944, 5649, 5650, 50, 5550, 44], [1, 1122, 5944, 5649, 5650], [1122, 5944, 5649, 5650], [1122, 5944], [5649, 5650], [5649], [5650], [50, 5550, 44], [50], [5550, 44], [5550], [44], [9, 1563], [1563], [11, 233, 143, 1628, 3, 1, 491, 7219, 3, 787, 530], [11], [233, 143, 1628, 3, 1, 491, 7219, 3, 787, 530], [233], [143, 1628, 3, 1, 491, 7219, 3, 787, 530], [143, 1628], [143], [1628], [3, 1, 491, 7219, 3, 787, 530], [3], [1, 491, 7219, 3, 787, 530], [1, 491, 7219], [491, 7219], [491], [7219], [3, 787, 530], [787, 530], [787], [530], [7, 1, 816, 166, 1221, 110], [1, 816, 166, 1221, 110], [816, 166, 1221, 110], [816, 166], [1221, 110], [1221], [110], [294, 22, 123, 49, 14, 1711, 1, 17, 468, 2, 3491, 326], [294, 22, 123, 49, 14, 1711], [294], [22, 123, 49, 14, 1711], [22], [123, 49, 14, 1711], [123], [49, 14, 1711], [49], [14, 1711], [14], [1711], [1, 17, 468, 2, 3491, 326], [], [1, 17, 468, 2, 3491, 326], [1, 17], [17], [468, 2, 3491, 326], [468, 2, 3491, 326], [468], [2, 3491, 326], [3491, 326], [3491], [326], [60, 5157, 3760, 60, 91, 207, 2, 225, 30, 1, 3446, 9941, 4, 53, 90, 1552, 369, 3, 34, 18, 9942, 152, 10508, 6401], [60], [5157, 3760, 60, 91, 207, 2, 225, 30, 1, 3446, 9941, 4, 53, 90, 1552, 369, 3, 34, 18, 9942, 152, 10508, 6401], [5157, 3760, 60, 91, 207, 2, 225, 30, 1, 3446, 9941, 4, 53, 90, 1552, 369, 3, 34, 18, 9942, 152, 10508, 6401], [5157], [3760, 60, 91, 207, 2, 225, 30, 1, 3446, 9941, 4, 53, 90, 1552, 369, 3, 34, 18, 9942, 152, 10508, 6401], [3760], [60, 91, 207, 2, 225, 30, 1, 3446, 9941, 4, 53, 90, 1552, 369, 3, 34, 18, 9942, 152, 10508, 6401], [60, 91, 207, 2, 225, 30, 1, 3446, 9941, 4], [60, 91, 207, 2, 225, 30, 1, 3446, 9941], [91, 207, 2, 225, 30, 1, 3446, 9941], [91], [207, 2, 225, 30, 1, 3446, 9941], [2, 225, 30, 1, 3446, 9941], [2, 225], [225], [30, 1, 3446, 9941], [30], [1, 3446, 9941], [3446, 9941], [3446], [9941], [4], [53, 90, 1552, 369, 3, 34, 18, 9942, 152, 10508, 6401], [53], [90, 1552, 369, 3, 34, 18, 9942, 152, 10508, 64 ...

# %%
from keras.preprocessing import sequence
from keras.preprocessing.text import one_hot
from keras.utils import to_categorical

maxWordCount=60

#padding all text to same size
trainX_encodedPadded_words = sequence.pad_sequences(encoded_words_train, maxlen=maxWordCount)
testX_encodedPadded_words = sequence.pad_sequences(encoded_words_test, maxlen=maxWordCount)

# One Hot Encoding
trainY = to_categorical(trainY, 5)

# %%
testX_encodedPadded_words
# Out:
# array([[   0,    0,    0, ...,  528, 1020,  397],
#        [   0,    0,    0, ...,  528, 1020,  397],
#        [   0,    0,    0, ...,    0,    0,   16],
#        ...,
#        [   0,    0,    0, ...,    2,  118, 4456],
#        [   0,    0,    0, ...,    2,  118, 4456],
#        [   0,    0,    0, ...,    0,  343, 1623]], dtype=int32)

# %%
from keras.optimizers import SGD, Adam, Nadam, RMSprop
from keras.models import Sequential,Model,load_model
from keras.layers import Embedding,Conv1D,MaxPooling1D
from keras.layers.core import Dense, Activation,Dropout ,Flatten
from keras.layers.recurrent import LSTM
from keras.constraints import maxnorm
import keras
model = Sequential()
output_dim = 16
model.add(Embedding(tokenizer_vocab_size, output_dim, input_length = maxWordCount))
model.add(LSTM(32))
model.add(Dropout(0.6))
#model.add(Dense(1200, activation='relu',W_constraint=maxnorm(1)))
# model.add(Dropout(0.6))
model.add(Dense(32, activation='relu',W_constraint=maxnorm(1)))

# model.add(Dropout(0.5))
 #output layer
model.add(Dense(5, activation='softmax'))

Nadam = keras.optimizers.Nadam(lr=0.002, beta_1=0.9, beta_2=0.999, epsilon=1e-08, schedule_decay=0.004)
model.compile(loss='categorical_crossentropy', optimizer=Nadam, metrics=['accuracy'])
# Out:
# /anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:16: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(32, activation="relu", kernel_constraint=<keras.con...)`

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_6 (Embedding)      (None, 60, 16)            284496
# _________________________________________________________________
# lstm_6 (LSTM)                (None, 32)                6272
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_10 (Dense)             (None, 32)                1056
# _________________________________________________________________
# dense_11 (Dense)             (None, 5)                 165
# =================================================================
# Total params: 291,989
# Trainable params: 291,989
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs=10
batch_size=32
model.fit(trainX_encodedPadded_words, trainY, epochs = epochs, batch_size=batch_size, verbose=1)
# Out:
# Epoch 1/10
#  - ETA: 305s - loss: 1.0702 - acc: 0.5694

# %%
f = open('Submission.csv', 'w')
f.write('PhraseId,Sentiment\n')


# predictions = model.predict(X_test_encodedPadded_words)
predicted_classes = model.predict_classes(testX_encodedPadded_words, batch_size=batch_size, verbose=1)
# print np.sum(predicted_classes==Y_Val2)/(1.0*Y_Val2.shape[0])
# print predicted_classes
# preds = new_model.predict(x)
# print predicted_classes
for i in range(0,X_test_PhraseID.shape[0]):
    # pred =np.argmax(predictions[i])
    f.write(str(X_test_PhraseID[i])+","+str(predicted_classes[i])+'\n')
    # print predictions[i],"=>",pred

f.close()
